# %% [markdown]
# # Table to LLM
# - Will rip HTML from websites
# - Raw HTML will be either:
#     - Processed to remove most tags using some Python
#     - Porcessed directly by the LLM
# - Chunk, embed and upsert the final data into a vector database
# - Query it with user input

# %%
# Setup

import os
import re
import json
import uuid
import yaml
import random
import tiktoken
import requests
import pandas as pd
from io import StringIO
from dotenv import load_dotenv
from bs4 import BeautifulSoup
import markdown
import chromadb
from chromadb.config import Settings

# %%
# Vars

load_dotenv()
openai_api_key = os.getenv('OPENAI_API_KEY')
together_api_key = os.getenv('TOGETHER_API_KEY')

# %%
# Data

data_types = ['txt', 'html', 'json', 'md', 'yaml']
file_df = pd.read_csv(r"..\Data\Other\html_data.csv")
file_df.head(3)
# Out:
#    Index                                                URL  Num of Tables  \
# 0      1  https://support.microsoft.com/en-us/office/int...              1
# 1      2  https://support.microsoft.com/en-us/office/for...              1
# 2      3  https://support.microsoft.com/en-us/office/vid...              1
#
#    Pictures of Tables Dynamic Dropdown Note
# 0                   0               No    -
# 1                   0               No    -
# 2                   0               No    -

# %%
# ChromaDB

chroma_client = chromadb.Client(settings=Settings(allow_reset=True))
chroma_client.reset()
collection = chroma_client.create_collection(name="copilot")

# %% [markdown]
# ## Functions

# %%
# Data File Related

def fetch_html(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return response.text
        else:
            print(f"Failed to retrieve HTML. Status code: {response.status_code}")
            return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
# LLM API Functions

def make_openai_call(payload):
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {openai_api_key}',
    }
    response = requests.post('https://api.openai.com/v1/chat/completions', json=payload, headers=headers)
    
    result = response.json()

    input_tokens = result['usage']['prompt_tokens']
    output_tokens = result['usage']['completion_tokens']
    result_text = result['choices'][0]['message']['content']

    return input_tokens, output_tokens, result_text
    
def make_together_call(payload):
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {together_api_key}',
    }
    # print(headers)
    response = requests.post('https://api.together.xyz/v1/chat/completions', json=payload, headers=headers)
    # print(response)
    
    result = response.json()
    # print(result)

    result_text = result['choices'][0]['message']['content']
    # print(result_text)

    return result_text

# %%
# CUSTOM Chunking Related

def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

def chunk_text(text, encoding_name, max_tokens=2000):
    """
    Splits text into chunks with each chunk having a maximum of max_tokens tokens.
    """
    chunks = []
    current_chunk = ""
    words = text.split()
    for word in words:
        # Simulate adding the word to the current chunk and check the token count
        test_chunk = current_chunk + " " + word if current_chunk else word
        if num_tokens_from_string(test_chunk, encoding_name) <= max_tokens:
            current_chunk = test_chunk
        else:
            # Current chunk is full, start a new one
            chunks.append(current_chunk)
            current_chunk = word
    # Add the last chunk if it's not empty
    if current_chunk:
        chunks.append(current_chunk)
    return chunks

def chunk_text_with_overlap(text, overlap_percentage=10, chunk_size=1024):
    # Example chunking logic with overlap, adjust as necessary
    chunks = []
    overlap_size = int(chunk_size * (overlap_percentage / 100))
    start = 0
    while start < len(text):
        end = min(start + chunk_size, len(text))
        chunks.append(text[start:end])
        start += (chunk_size - overlap_size)
    return chunks

# %%
# Extract DF from Formats

def extract_tables_from_html(html_content: str) -> pd.DataFrame:
    """Extract tables from HTML content and return them as a list of pandas DataFrames."""
    soup = BeautifulSoup(html_content, 'html.parser')
    html_io = StringIO(html_content)
    return pd.read_html(html_io)[0]
    # return [pd.read_html(str(table))[0] for table in soup.find_all('table')]

def extract_tables_from_json(json_content: str) -> pd.DataFrame:
    """Extract tables from JSON content and return them as a list of pandas DataFrames."""
    data = json.loads(json_content)
    return pd.DataFrame(list(data.values())[0])
    # return [pd.DataFrame(table_data) for table_data in data.values()]

def extract_tables_from_md(md_content: str) -> pd.DataFrame:
    """Convert Markdown content to HTML and extract tables from it."""
    html_content = markdown.markdown(md_content)
    return extract_tables_from_html(html_content)
    # return extract_tables_from_html(html_content)

def extract_tables_from_file(html_text: str, source: str) -> pd.DataFrame:
    """Extract tables from HTML content string based on its extension."""

    if source == "html":
        return extract_tables_from_html(html_text)
    elif source.endswith('.json'):
        return extract_tables_from_json(html_text)
    elif source.endswith('.md'):
        return extract_tables_from_md(html_text)
    else:
        raise ValueError("Unsupported file format")

# %%
# Convert DF to Formats

def dataframe_to_text(dataframe: pd.DataFrame) -> str:
    """Convert a pandas DataFrame to a text format."""
    return dataframe.to_string(index=False)

def dataframe_to_html(dataframe: pd.DataFrame) -> str:
    """Convert a pandas DataFrame to HTML format."""
    return dataframe.to_html(index=False)

def dataframe_to_json(dataframe: pd.DataFrame) -> str:
    """Convert a pandas DataFrame to JSON format."""
    return dataframe.to_json(orient='records', indent=4)

def dataframe_to_md(dataframe: pd.DataFrame) -> str:
    """Convert a pandas DataFrame to Markdown format by first converting to HTML."""
    return markdown.markdown(dataframe.to_html(index=False))

def dataframe_to_yaml(dataframe: pd.DataFrame) -> str:
    """Convert a pandas DataFrame to YAML format."""
    return yaml.dump(dataframe.to_dict(orient='records'), default_flow_style=False)

def print_format_from_table(print_format: str, dataframe: pd.DataFrame) -> None:
    """Print or save a pandas DataFrame in the specified format."""
    format_functions = {
        'html': dataframe_to_html,
        'json': dataframe_to_json,
        'md': dataframe_to_md,
        'txt': dataframe_to_text,
        'yaml': dataframe_to_yaml
    }
    
    if print_format not in format_functions:
        raise ValueError("Unsupported save format")

    print_content = format_functions[print_format](dataframe)
    return print_content

# %%
# HTML Processing with Python/LLM

def python_strip_most_tags(html_content: str) -> str:
    # Remove most HTML tags and convert the table tag content into whatever format needed
    
    # Parse HTML content
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Remove all tags except for <table> tags
    for tag in soup.find_all(True):
        if tag.name != 'table':
            tag.unwrap()

    # Get text
    cleaned_html = soup.get_text(separator=' ')
    cleaned_html = re.sub(r'\s+', ' ', cleaned_html).strip()

    return cleaned_html

def llm_strip_most_tags(html_content: str) -> str:
    # Remove most HTML tags and convert the table tag content into whatever format needed

    num_tokens_in_html = num_tokens_from_string(html_content, "cl100k_base")
    print(F"HTML contains {num_tokens_in_html} tokens")

    # Call split_html function to split html_content
    html_parts = chunk_text(html_content, "cl100k_base", 2048)
    
    # Initialize cleaned_html variable to store concatenated results
    cleaned_html = ''
    
    # Loop through each part of the html_content
    for part in html_parts:
        payload = {
            'messages': [
                {
                    'role': 'system',
                    'content': f"You are a system that takes in raw HTML and processes it to remove all tags and format the data in plain text. Write the headers correctly and then just print the row values."
                },
                {
                    'role': 'user', 
                    'content': f"{part}"
                }
            ],
            'model': "gpt-3.5-turbo",
            'max_tokens': 2048,
            "temperature": 0.0,
            "seed": 48
        }
        print(payload)
        cleaned_html += make_openai_call(payload)
    
    return cleaned_html

# %%
def process_html(raw_html, output_format, summarize=False):
    soup = BeautifulSoup(raw_html, 'html.parser')

    # Find all table elements
    tables = soup.find_all('table')
    print(f"Num of Table Elements: {len(tables)}")
    
    top_level_tables = [table for table in tables if not table.find_parent('table')]
    print(f"Num of Parent Table Elements: {len(top_level_tables)}")

    # Filter out tables that are just wrappers for images or have insufficient content
    tables_with_content = []
    for table in top_level_tables:
        # Count all the elements within each table
        all_elements = table.find_all(True)
        # Count all the img tags within each table
        img_elements = table.find_all('img')
        
        # Count non-empty cells and img wrappers
        non_empty_cells = [cell for cell in table.find_all('td') if cell.get_text(strip=True)]
        img_wrappers = [cell for cell in table.find_all('td') if cell.find('img')]
        
        # Adjust condition to filter out tables that are primarily image wrappers or have insufficient content
        if len(non_empty_cells) > 0 and len(all_elements) - len(img_elements) > len(img_wrappers):
            tables_with_content.append(table)
    print(f"Num of Filtered Parent Table Elements: {len(tables_with_content)}")

    table_formatted = []
    for i, table in enumerate(tables_with_content):
        print(f"Table {i}")
        
        # Using table's HTML format instead of summaryu
        soup_table_df = extract_tables_from_file(str(table), "html")
        # print(soup_table_df)
        
        soup_table_format = print_format_from_table(output_format, soup_table_df)
        # print(soup_table_format)

        if not summarize:
            table_formatted.append(soup_table_format)
        else:
            payload = {
                'messages': [
                    {
                        'role': 'system',
                        'content': f"You are a helpful assistant that takes as input raw dump of a table and summarizes it. Create a title for the table and explain each row in a line of text."
                    },
                    {
                        'role': 'user', 
                        'content': f"{soup_table_format}"
                    }
                ],
                'model': "openchat/openchat-3.5-1210",
                'max_tokens': 2048,
                "temperature": 0.0
            }
            soup_table_summary = make_together_call(payload)
            # print(f"soup_table_summary\n{soup_table_summary}")

            table_formatted.append(soup_table_summary)

        # You might want to remove the table or replace it with a placeholder
        table.extract()

    # Remove all tags from the soup and keep only text
    text_only = soup.get_text(separator=' ', strip=True)

    return text_only, table_formatted

# %%
def insert_random(string, fixed_string):
    # Generate a random index within the range of the existing string
    index = random.randint(0, len(string))
    
    # Insert the fixed string at the random index
    new_string = string[:index] + fixed_string + string[index:]
    
    return new_string

# %% [markdown]
# ## Saving HTML Data

# %%
# Pull all URLs from file
file_df = pd.read_csv(r"..\Data\Other\html_data.csv")
print(f"CSV Data\n{file_df.head(3)}\n")

all_urls = file_df['URL'].tolist()
print(f"All URLs\n{all_urls}")
# Out:
# CSV Data
#    Index                                                URL  Num of Tables  \
# 0      1  https://support.microsoft.com/en-us/office/int...              1
# 1      2  https://support.microsoft.com/en-us/office/for...              1
# 2      3  https://support.microsoft.com/en-us/office/vid...              1
#
#    Pictures of Tables Dynamic Dropdown Note
# 0                   0               No    -
# 1                   0               No    -
# 2                   0               No    -
#
# All URLs
# ['https://support.microsoft.com/en-us/office/introduction-to-tables-78ff21ea-2f76-4fb0-8af6-c318d1ee0ea7', 'https://support.microsoft.com/en-us/office/format-a-table-e6e77bc6-1f4e-467e-b818-2e2acc488006', 'https://support.microsoft.com/en-us/office/video-get-started-with-table-relationships-728d53ff-f332-4ac6-9382-574ee271500a', 'https://support.microsoft.com/en-us/office/resize-a-table-column-or-row-9340d478-21be-4392-81cf-488f7bbd6715', 'https://support.microsoft.com/en-us/office/using-structured-references-with-excel-tables-f5ed2452-2337-4f71-bed3-c8ae6d2b276e', 'https://support.microsoft.com/en-us/office/how-can-i-merge-two-or-more-tables-c80a9fce-c1ab-4425-bb96-497dd906d656', 'https://support.microsoft.com/en-us/office/create-a-form-that-contains-a-subform-a-one-to-many-form-ddf3822f-8aba-49cb-831a-1e74d6f5f06b', 'https://support.microsoft.com/en-us/office/relationships-between-tables-in-a-data-model-533dc2b6-9288-4363-9538-8ea6e469112b', 'https://support.microsoft.com/en-us/office/xlookup-function-b7fd680e-6d10-43e6-84f9-88eae8bf5929', 'https://support.microsoft.com/en-us/office/introduction-to-what-if-analysis-22bffa5f-e891-4acc-bf7a-e4645c446fb4', 'https://support.microsoft.com/en-us/office/dataverse-system-tables-and-columns-5a6b5528-24d5-451a-ad7b-dc7a52dab470', 'https://support.microsoft.com/en-us/office/calculate-values-in-a-pivottable-11f41417-da80-435c-a5c6-b0185e59da77', 'https://support.microsoft.com/en-us/office/compare-two-tables-in-access-and-find-only-matching-data-16f301ac-40c1-43bc-80db-263f9a51eb4f', 'https://support.microsoft.com/en-us/office/add-records-to-a-table-by-using-an-append-query-98a5bd66-2190-4243-9638-8ef649cf3596', 'https://support.microsoft.com/en-us/office/subtotal-and-total-fields-in-a-pivottable-173f5b30-b546-4293-87d2-aee638f74e7d', 'https://support.microsoft.com/en-us/office/what-is-the-relationships-window-20c66348-854f-47f8-819a-5cce2518ee1d', 'https://support.microsoft.com/en-us/office/use-the-name-manager-in-excel-4d8c4c2b-9f7d-44e3-a3b4-9f61bd5c64e4', 'https://support.microsoft.com/en-us/office/relationships-between-tables-in-a-data-model-533dc2b6-9288-4363-9538-8ea6e469112b', 'https://iapam.com/125-weight-loss-statistics-physicians-should-read']

# %%
# Save HTML content from each URL to a file
html_output_path = r"..\Data\HTML"
for index, single_url in enumerate(all_urls, start=1):
    html_content = fetch_html(single_url)
    if html_content:
        file_name = f"page_{index}.html"
        file_path = os.path.join(html_output_path, file_name)
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(html_content)
        print(f"HTML content saved to {file_path}")
# Out:
# HTML content saved to ..\Data\HTML\page_1.html
# HTML content saved to ..\Data\HTML\page_2.html
# HTML content saved to ..\Data\HTML\page_3.html
# HTML content saved to ..\Data\HTML\page_4.html
# HTML content saved to ..\Data\HTML\page_5.html
# HTML content saved to ..\Data\HTML\page_6.html
# HTML content saved to ..\Data\HTML\page_7.html
# HTML content saved to ..\Data\HTML\page_8.html
# HTML content saved to ..\Data\HTML\page_9.html
# HTML content saved to ..\Data\HTML\page_10.html
# HTML content saved to ..\Data\HTML\page_11.html
# HTML content saved to ..\Data\HTML\page_12.html
# HTML content saved to ..\Data\HTML\page_13.html
# HTML content saved to ..\Data\HTML\page_14.html
# HTML content saved to ..\Data\HTML\page_15.html
# HTML content saved to ..\Data\HTML\page_16.html
# HTML content saved to ..\Data\HTML\page_17.html
# HTML content saved to ..\Data\HTML\page_18.html
# Failed to retrieve HTML. Status code: 403

# %% [markdown]
# ## Multi URL Testing

# %%
master_list = []
html_folder_path = r"..\Data\HTML"
for file_name in os.listdir(html_folder_path):
    file_path = os.path.join(html_folder_path, file_name)
    with open(file_path, 'r', encoding='utf-8') as file:
        html = file.read()
    
    # Update to change summarized vs raw table
    cleaned_html, table_summaries = process_html(html, "html", True)
    document_id = str(uuid.uuid4())
    meta = {"source": file_path}

    # Handle table summaries as separate chunks
    for i, summary in enumerate(table_summaries):
        item = {
            "document": summary,
            "metadata": {"source": file_path, "type": "table_summary", "table_index": i},
            "id": f"{document_id}_table_{i}"
        }
        print(f"item\n{item}")
        master_list.append(item)

    # Chunk the remaining HTML with overlap
    remaining_chunks = chunk_text_with_overlap(cleaned_html, overlap_percentage=10)
    for i, chunk in enumerate(remaining_chunks):
        new_id = f"{document_id}_{i+len(table_summaries)}"  # Adjust index based on table summaries
        new_meta = meta.copy()
        new_meta["ind"] = i
        
        # Use insert_random to update the chunk
        distractor_string = f"""
        Genghis's senior nökod were appointed to the highest ranks and received the greatest honours. 
        Bo'orchu and Muqali were each given ten thousand men to lead as commanders of the right and left wings of the army respectively
        """
        distractor_insertion_perc = 0
        if random.randint(1, 100) <= distractor_insertion_perc:
            chunk = insert_random(chunk, distractor_string.strip())  

        new_item = {
            "document": chunk,
            "metadata": new_meta,
            "id": new_id
        }
        master_list.append(new_item)
# Out:
# Num of Table Elements: 2
# Num of Parent Table Elements: 1
# Num of Filtered Parent Table Elements: 1
# Table 0
# item
# {'document': ' Title: Data Types in Access Based on User Input\n\n1. If you enter "Short Text", Access creates a field with a data type of Short Text.\n2. If you enter a valid Internet protocol prefix (e.g., http://, https://, mailto:), Access creates a field with a data type of Hyperlink.\n3. If you enter a number, Access creates a field with a data type of Long Integer.\n4. If you enter a date and time, Access creates a field with a data type of Date/Time. The format recognized is based on the user\'s locale.\n5. If you enter a currency value, Access creates a field with a data type of Currency. The currency symbol recognized is based on the user\'s locale.\n6. If you enter a percentage value, Access creates a field with a data type of Double.\n7. If you enter a scientific notation value, Access creates a field with a data type of Double.', 'metadata': {'source': '..\\Data\\HTML\\page_1.html', 'type': 'table_summary', 'table_index': 0}, 'id': '974afc9b-16d7-4c53-b5ca-24530f6f9795_table_0'}
# Num of Table Elements: 0
# Num of Parent Table Elements: 0
# Num of Filtered Parent Table Elements: 0
# Num of Table Elements: 3
# Num of Parent Table Elements: 3
# Num of Filtered Parent Table Elements: 3
# Table 0
# Table 1
# Table 2
# item
# {'document': ' Title: Microsoft 365 Feature General Availability\n\nRow 1: The feature is in General Availability (GA) in the Microsoft 365 Monthly Release Channel since May 2022. For those on the Microsoft Semi-annual Enterprise Channel, it is available from December 2022. More information on participation can be found at aka.ms/AccessAndPowerPlatform.', 'metadata': {'source': '..\\Data\\HTML\\page_11.html', 'type': 'table_summary', 'table_index': 0}, 'id': '33148ddd-1304-4cc4-93b2-0b3749560730_table_0'}
# item
# {'document': ' Title: Dynamics 365 Table Summary\n\nCurrency:\nStores currency details for all transaction currencies, including exchange rate, name, symbol, code, and more. Required for Currency features (logical name: Transactioncurrency). Available in Dataverse and Dataverse for Teams, but not linked in Access.\n\nUsers:\nStores users of the organization that use the apps or data. Used in lookup columns created by default. Available in Dataverse and Dataverse for Teams, and linked in Access.\n\nTeams:\nStores teams of users in the organization that use the apps or data. Used in lookup columns created by default. Available in Dataverse and Dataverse for Teams, and linked in Access.\n\nBusiness Units:\nStores business units users belong to in the organization that use the apps or data. Used in lookup columns created by default. Available in Dataverse and Dataverse for Teams, and linked in Access.', 'metadata': {'source': '..\\Data\\HTML\\page_11.html', 'type': 'table_summary', 'table_index': 1}, 'id': '33148ddd-1304-4cc4-93b2-0b3749560730_table_1'}
# item
# {'document': " Title: Table Overview for Dataverse and Dataverse for Teams\n\n1. Primary Name: A user-friendly text string used to identify rows, chosen by the user.\n2. Primary ID: A unique identifier string used to identify rows, system-generated.\n3. CreatedBy: A lookup column to the users table, selecting the user who created the row.\n4. CreatedBy (Delegate): A lookup column to the users table, selecting the user who created the row as a delegate for another user.\n5. CreatedOn: A date time column recording the date and time a row was created, stored in UTC.\n6. Currency: A lookup to the Currency column to retrieve transaction currency details.\n7. Exchange Rate: The exchange rate value retrieved from the transaction currency at the time of row creation.\n8. Import Sequence Number: The row's place in the sequence of imported records.\n9. ModifiedBy: A lookup column to the users table, selecting the user who modified the row.\n10. ModifiedBy (Delegate): A lookup column to the users table, selecting the user who modified the row as a delegate for another user.\n11. ModifiedOn: A date time column recording the date and time a row was modified, stored in UTC.\n12. Owner: The unique OwnerID assigned to the user selected as the Owning User.\n13. Owning Business Unit: A lookup to the business unit table to select the appropriate business unit that owns the row.\n14. Owning Team: A lookup to the team table to select the appropriate team that owns the row.\n15. Owning User: A lookup to the user table to select the appropriate user that owns the row.\n16. Record Created On: Date and time that a row was migrated.\n17. Status: An option set that allows a user to pick the state of a row.\n18. Status Reason: An option set related to Status, allowing a user to pick the status reason of a row based on the status selected.\n19. Time Zone Rule Version: Internal only, used to determine which set of time zone rules apply.\n20. UTC Conversion Time Zone Code: The time zone offset code in use at the time the row was created.\n21. Version Number: The version number of a row used to track previous changes if auditing is enabled.", 'metadata': {'source': '..\\Data\\HTML\\page_11.html', 'type': 'table_summary', 'table_index': 2}, 'id': '33148ddd-1304-4cc4-93b2-0b3749560730_table_2'}
# Num of Table Elements: 6
# Num of Parent Table Elements: 6
# Num of Filtered Parent Table Elements: 4
# Table 0
# Table 1
# Table 2
# Table 3
# item
# {'document': ' Title: Summary Functions for Data Analysis\n\n- Sum: Calculates the total of all numeric values in the dataset.\n- Count: Determines the number of data values present.\n- Average: Computes the mean value of the dataset.\n- Max: Identifies the highest value in the dataset.\n- Min: Locates the lowest value in the dataset.\n- Product: Multiplies all values together to find the total product.\n- Count Nums: Counts the number of numeric values in the dataset.\n- StDev: Estimates the standard deviation of a population using a sample.\n- StDevp: Calculates the standard deviation of the entire population.\n- Var: Estimates the variance of a population using a sample.\n- Varp: Determines the variance of the entire population.', 'metadata': {'source': '..\\Data\\HTML\\page_12.html', 'type': 'table_summary', 'table_index': 0}, 'id': '268ed106-e1db-4b61-b4b7-a3eab5fd8608_table_0'}
# item
# {'document': " Title: Summary of Table Functions and Results\n\n1. No Calculation: Displays the value entered in the field.\n2. % of Grand Total: Displays values as a percentage of the overall grand total.\n3. % of Column Total: Displays column values as a percentage of their total.\n4. % of Row Total: Displays row values as a percentage of their total.\n5. % Of: Displays values as a percentage of the base item's value.\n6. % of Parent Row Total: Calculates values based on the parent item's row value.\n7. % of Parent Column Total: Calculates values based on the parent item's column value.\n8. % of Parent Total: Calculates values based on the parent item's total value.\n9. Difference From: Displays values as the difference from the base item's value.\n10. % Difference From: Displays values as the percentage difference from the base item's value.\n11. Running Total in: Displays successive item values as a running total.\n12. % Running Total in: Displays running total as a percentage.\n13. Rank Smallest to Largest: Ranks values in ascending order, with the smallest value as 1.\n14. Rank Largest to Smallest: Ranks values in descending order, with the largest value as 1.\n15. Index: Calculates values based on the formula provided.", 'metadata': {'source': '..\\Data\\HTML\\page_12.html', 'type': 'table_summary', 'table_index': 1}, 'id': '268ed106-e1db-4b61-b4b7-a3eab5fd8608_table_1'}
# item
# {'document': ' Title: Summary Functions for Data Analysis\n\n1. Sum: Calculates the total sum of numeric values in a field.\n2. Count: Determines the number of nonempty values in a field.\n3. Average: Computes the average value of a field.\n4. Max: Identifies the largest value in a field.\n5. Min: Finds the smallest value in a field.\n6. Product: Calculates the product of all values in a field.\n7. Count Numbers: Counts the number of values containing numbers, excluding non-numeric values.\n8. StDev: Estimates the standard deviation of a population using a sample.\n9. StDevp: Calculates the standard deviation of a population using the entire dataset.\n10. Var: Estimates the variance of a population using a sample.\n11. Varp: Calculates the variance of a population using the entire dataset.', 'metadata': {'source': '..\\Data\\HTML\\page_12.html', 'type': 'table_summary', 'table_index': 2}, 'id': '268ed106-e1db-4b61-b4b7-a3eab5fd8608_table_2'}
# item
# {'document': ' Title: Summary Functions for Data Analysis\n\n1. Sum: Calculates the total sum of numeric values in a field.\n2. Count: Determines the number of nonempty values in a field.\n3. Average: Computes the average value of a field.\n4. Max: Identifies the largest value in a field.\n5. Min: Finds the smallest value in a field.\n6. Product: Calculates the product of all values in a field.\n7. Count Numbers: Counts the number of values containing numbers, excluding non-numeric values.\n8. StDev: Estimates the standard deviation of a population using a sample.\n9. StDevp: Calculates the standard deviation of a population using the entire dataset.\n10. Var: Estimates the variance of a population using a sample.\n11. Varp: Calculates the variance of a population using the entire dataset.', 'metadata': {'source': '..\\Data\\HTML\\page_12.html', 'type': 'table_summary', 'table_index': 3}, 'id': '268ed106-e1db-4b61-b4b7-a3eab5fd8608_table_3'}
# Num of Table Elements: 2
# Num of Parent Table Elements: 2
# Num of Filtered Parent Table Elements: 2
# Table 0
# Table 1
# item
# {'document': " Title: Student Enrollment by Major and Year\n\nEach row represents a student's enrollment in a specific major for the year 2005 or 2006. The table includes the student ID, the year of enrollment, and the major they are pursuing.", 'metadata': {'source': '..\\Data\\HTML\\page_13.html', 'type': 'table_summary', 'table_index': 0}, 'id': 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_table_0'}
# item
# {'document': ' Title: Student Course Grades by Year and Term\n\nSummary:\nThe table displays student course grades by year, term, curriculum, course number, and grade. Each row represents a unique combination of student ID, year, term, curriculum, course number, and grade. The data spans from 2005 to 2006 and includes courses in various subjects such as MATH, ENGL, POSC, PSYC, HIST, ARTH, BIOL, CHEM, and STAT.', 'metadata': {'source': '..\\Data\\HTML\\page_13.html', 'type': 'table_summary', 'table_index': 1}, 'id': 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_table_1'}
# Num of Table Elements: 2
# Num of Parent Table Elements: 2
# Num of Filtered Parent Table Elements: 2
# Table 0
# Table 1
# item
# {'document': ' Title: SQL Query Criteria and Effects\n\n1. > 234: Returns all numbers greater than 234.\n2. >= "Callahan": Returns all records from Callahan through the end of the alphabet.\n3. Between #2/2/2017# And #12/1/2017#: Returns dates from 2-Feb-17 through 1-Dec-17 (ANSI-89).\n4. Not "Germany": Finds all records where the exact contents of the field are not exactly equal to "Germany."\n5. Not "T*": Finds all records except those beginning with T.\n6. Not "*t": Finds all records that do not end with t.\n7. In(Canada,UK): Finds all records containing Canada or UK.\n8. Like "[A-D]*": Finds all records that start with the letters A through D.\n9. Like "*ar*": Finds all records that include the letter sequence "ar".\n10. Like "Maison Dewe?": Finds all records that begin with "Maison" and contain a 5-letter second string with specific conditions.\n11. #2/2/2017#: Finds all records for February 2, 2017.\n12. < Date() - 30: Returns all dates more than 30 days old.\n13. Date(): Returns all records containing today\'s date.\n14. Between Date() And DateAdd("M", 3, Date()): Returns all records between today\'s date and three months from today\'s date.\n15. Is Null: Returns all records with a null (blank or undefined) value.\n16. Is Not Null: Returns all records with a value.\n17. "": Returns all records with a zero-length string.', 'metadata': {'source': '..\\Data\\HTML\\page_14.html', 'type': 'table_summary', 'table_index': 0}, 'id': '3135dcf7-c7ac-45f1-9c06-c1c37d76bd4f_table_0'}
# item
# {'document': ' Title: "Behavior of Field Addition in Table Append Operations"\n\n1. When all fields from the source table or query are added, the destination table\'s fields are added to the Append to row in the design grid.\n2. If individual fields are added to the query with matching names in both source and destination tables, the matching destination fields are automatically added to the Append to row in the query.\n3. If individual fields or expressions are added with unmatched names in the source and destination tables, the matching fields are added, and unmatched fields remain blank.', 'metadata': {'source': '..\\Data\\HTML\\page_14.html', 'type': 'table_summary', 'table_index': 1}, 'id': '3135dcf7-c7ac-45f1-9c06-c1c37d76bd4f_table_1'}
# Num of Table Elements: 1
# Num of Parent Table Elements: 1
# Num of Filtered Parent Table Elements: 1
# Table 0
# item
# {'document': ' Title: Summary Functions for Data Analysis\n\n1. Sum: Calculates the total of all numeric values in the dataset.\n2. Count: Determines the number of data values present.\n3. Average: Computes the mean value of the dataset.\n4. Max: Identifies the highest value in the dataset.\n5. Min: Locates the lowest value in the dataset.\n6. Product: Multiplies all values together to find the total product.\n7. Count Numbers: Counts the number of values that are numerical.\n8. StDev: Estimates the standard deviation of a population using a sample.\n9. StDevp: Calculates the standard deviation of the entire population.\n10. Var: Estimates the variance of a population using a sample.\n11. Varp: Determines the variance of the entire population.', 'metadata': {'source': '..\\Data\\HTML\\page_15.html', 'type': 'table_summary', 'table_index': 0}, 'id': '1bb2286b-5f5e-4fe5-8680-b6bcc75f03d5_table_0'}
# Num of Table Elements: 1
# Num of Parent Table Elements: 1
# Num of Filtered Parent Table Elements: 1
# Table 0
# item
# {'document': ' Title: Access Database Table Management and Relationships\n\n1. Add a table or query to the window: Click Design > Add Tables (Show Table in Access 2013), select the table or query you want, and then click Add.\n2. Delete a table or query from the window: Select the table or query, and then press DELETE.\n3. Hide a table or query: Right-click the table or query, and then click Hide Table.\n4. Create a relationship: Drag a field from one table or query to the corresponding field in the other table or query.\n5. Set properties for a relationship: Right-click the relationship line between two tables, and then click Edit Relationship.\n6. Delete a relationship: Right-click the relationship line between two tables, and then click Delete.\n7. Show all relationships: Click Design > All Relationships.\n8. View the relationships for a particular table: Click Design > Direct Relationships after selecting the table.\n9. View the relationships for one table without viewing the relationships for other tables: Click Design > Tools > Clear Layout, add the table you want to see relationships for, and then click Design > Relationships > Direct Relationships.\n10. Adjust a table size to reveal additional fields and relationships (Requires Access for Microsoft 365): Right-click a table and select Size to Fit, or double-click a table edge to size it horizontally or vertically.\n11. Select a subset of tables (Requires Access for Microsoft 365): CTRL + (select multiple tables), click and drag a box around the selected range, or move and unselect the selection.\n12. Use the mouse scroll wheel (Requires Access for Microsoft 365): Scroll vertically by scrolling the mouse wheel, and scroll horizontally by pressing Shift and then scrolling the mouse wheel.', 'metadata': {'source': '..\\Data\\HTML\\page_16.html', 'type': 'table_summary', 'table_index': 0}, 'id': '1ccc795c-0697-4534-9928-d5fa8f09f85f_table_0'}
# Num of Table Elements: 2
# Num of Parent Table Elements: 2
# Num of Filtered Parent Table Elements: 2
# Table 0
# Table 1
# item
# {'document': ' Title: Excel Table Name and Reference Information\n\n1. Name: The name of the table, which can be a defined name, a table name, or a default name created by Excel.\n2. Value: The current value of the name, such as a formula result, string constant, cell range, error, array of values, or placeholder.\n3. Refers To: The current reference for the name, such as a cell range, formula, or workbook-level reference.\n4. Scope: The level at which the name is defined, either the local worksheet level or the global workbook level.\n5. Comment: Additional information about the name, up to 255 characters.\n6. Refers to: The reference for the selected name, which can be edited for quick changes to the range of the name.', 'metadata': {'source': '..\\Data\\HTML\\page_17.html', 'type': 'table_summary', 'table_index': 0}, 'id': 'e58dd423-12cb-46b3-9432-d5c31e5a56a0_table_0'}
# item
# {'document': ' Title: "Excel Named Range Filters"\n\n1. Names Scoped To Worksheet: Displays local names within a specific worksheet.\n2. Names Scoped To Workbook: Displays global names across the entire workbook.\n3. Names With Errors: Displays names with error-containing values (e.g., #REF, #VALUE, #NAME).\n4. Names Without Errors: Displays names with error-free values.\n5. Defined Names: Displays names defined by the user or Excel, such as print areas.\n6. Table Names: Displays only table names within the workbook.', 'metadata': {'source': '..\\Data\\HTML\\page_17.html', 'type': 'table_summary', 'table_index': 1}, 'id': 'e58dd423-12cb-46b3-9432-d5c31e5a56a0_table_1'}
# Num of Table Elements: 6
# Num of Parent Table Elements: 6
# Num of Filtered Parent Table Elements: 6
# Table 0
# Table 1
# Table 2
# Table 3
# Table 4
# Table 5
# item
# {'document': ' Title: Customer Orders and Discount Rates\n\nRow 1: Ashton with email chris.ashton@contoso.com has a 5% discount rate. They ordered Compact Digital (11 units) and SLR Camera (15 units) on January 7th and January 3rd, 2010 respectively.\n\nRow 2: Jaworski with email michal.jaworski@contoso.com has a 10% discount rate. They ordered Budget Movie-Maker (27 units) on January 3rd, 2010.', 'metadata': {'source': '..\\Data\\HTML\\page_18.html', 'type': 'table_summary', 'table_index': 0}, 'id': '1ba0e7f0-0742-463b-a760-4ef91a7d9f69_table_0'}
# item
# {'document': ' Title: Customer Information\n\nRow 1: CustomerID 1, Name Ashton, Email chris.ashton@contoso.com\nRow 2: CustomerID 2, Name Jaworski, Email michal.jaworski@contoso.com', 'metadata': {'source': '..\\Data\\HTML\\page_18.html', 'type': 'table_summary', 'table_index': 1}, 'id': '1ba0e7f0-0742-463b-a760-4ef91a7d9f69_table_1'}
# item
# {'document': ' Title: Customer Discount Rates\n\nRow 1: CustomerID 1 receives a 5% discount rate.\nRow 2: CustomerID 2 receives a 10% discount rate.', 'metadata': {'source': '..\\Data\\HTML\\page_18.html', 'type': 'table_summary', 'table_index': 2}, 'id': '1ba0e7f0-0742-463b-a760-4ef91a7d9f69_table_2'}
# item
# {'document': ' Title: Customer Orders Summary\n\nRow 1: Customer ID 1 placed an order for 11 Compact Digital products on January 7, 2010.\nRow 2: Customer ID 1 also placed an order for 15 SLR Cameras on January 3, 2010.\nRow 3: Customer ID 2 placed an order for 27 Budget Movie-Makers on January 3, 2010.', 'metadata': {'source': '..\\Data\\HTML\\page_18.html', 'type': 'table_summary', 'table_index': 3}, 'id': '1ba0e7f0-0742-463b-a760-4ef91a7d9f69_table_3'}
# item
# {'document': ' Title: "Customer Relationships and Lookup Columns"\n\n1. Customers-CustomerDiscounts: A one-to-one relationship where the CustomerID is used in both Customers.CustomerID and CustomerDiscounts.CustomerID columns.\n2. Customers-Orders: A one-to-many relationship where the CustomerID is used in both Customers.CustomerID and Orders.CustomerID columns.', 'metadata': {'source': '..\\Data\\HTML\\page_18.html', 'type': 'table_summary', 'table_index': 4}, 'id': '1ba0e7f0-0742-463b-a760-4ef91a7d9f69_table_4'}
# item
# {'document': ' Title: Data Modeling Criteria and Descriptions\n\n1. Unique Identifier for Each Table: Each table must have a primary key column that uniquely identifies each row.\n2. Unique Lookup Columns: Lookup columns must have unique data values, with no duplicates or nulls.\n3. Compatible Data Types: Source and lookup columns must have compatible data types.', 'metadata': {'source': '..\\Data\\HTML\\page_18.html', 'type': 'table_summary', 'table_index': 5}, 'id': '1ba0e7f0-0742-463b-a760-4ef91a7d9f69_table_5'}
# Num of Table Elements: 1
# Num of Parent Table Elements: 1
# Num of Filtered Parent Table Elements: 1
# Table 0
# item
# {'document': ' Title: "Top 10 U.S. States with the Highest Obesity Rates"\n\n1. Mississippi: 40.8% obesity rate\n2. West Virginia: 39.7% obesity rate\n3. Arkansas: 37.4% obesity rate\n4. Oklahoma: 36.8% obesity rate\n5. Kentucky: 36.5% obesity rate\n6. Tennessee: 36.5% obesity rate\n7. Alabama: 36.1% obesity rate\n8. Michigan: 36% obesity rate\n9. Louisiana: 35.9% obesity rate\n10. South Carolina: 35.4% obesity rate', 'metadata': {'source': '..\\Data\\HTML\\page_19.html', 'type': 'table_summary', 'table_index': 0}, 'id': 'f22b30a1-24dc-4a39-b904-13d6e1e1cdac_table_0'}
# Num of Table Elements: 2
# Num of Parent Table Elements: 2
# Num of Filtered Parent Table Elements: 2
# Table 0
# Table 1
# item
# {'document': ' Title: "Table Editing Options"\n\n1. Shift cells right: Insert a cell and move all other cells in the same row to the right, potentially resulting in a row with more cells than others.\n2. Shift cells down: Insert a cell and move remaining existing cells in the same column down one row each, adding a new row at the bottom to contain the last existing cell.\n3. Insert entire row: Insert a row just above the clicked cell.\n4. Insert entire column: Insert a column just to the right of the clicked cell.', 'metadata': {'source': '..\\Data\\HTML\\page_2.html', 'type': 'table_summary', 'table_index': 0}, 'id': '55befabe-a8dc-488c-95e2-ef65e71b208e_table_0'}
# item
# {'document': ' Title: "Table Selection Techniques"\n\n1. To select a single cell, click the left edge of the cell.\n2. To select an entire row, click to the left of the row.\n3. To select an entire column, click the column\'s top gridline or top border.', 'metadata': {'source': '..\\Data\\HTML\\page_2.html', 'type': 'table_summary', 'table_index': 1}, 'id': '55befabe-a8dc-488c-95e2-ef65e71b208e_table_1'}
# Num of Table Elements: 5
# Num of Parent Table Elements: 5
# Num of Filtered Parent Table Elements: 5
# Table 0
# Table 1
# Table 2
# Table 3
# Table 4
# item
# {'document': ' Title: Employee Information\n\nAshton Brady: Accountant at London office, 36 years old, earning 162,700.\nMiles Tenner: Integration Specialist in San Francisco, 41 years old, earning 372,000.\nHarvey Spencer: Regional Director in London, 42 years old, earning 470,600.\nMike Sallanger: Personnel Lead in New York, 38 years old, earning 220,500.\nJaden Hyatt: Team Lead in London, 35 years old, earning 240,700.\nDonna Hannigan: Senior Marketing Designer in San Francisco, 36 years old, earning 275,100.\nNile Harris: Development Lead in New York, 37 years old, earning 345,200.\nAllison Kram: Integration Specialist in Sydney, 34 years old, earning 270,000.\nVictor Vincent: Accountant in Sydney, 40 years old, earning 170,500.\nBob Randell: Accountant in New York, 41 years old, earning 190,750.\n\nNote: The last row appears to be incomplete or incorrect, as it contains the same information repeated for each column.', 'metadata': {'source': '..\\Data\\HTML\\page_20.html', 'type': 'table_summary', 'table_index': 0}, 'id': '2ec281eb-180a-4fd6-97e3-51d4b928320c_table_0'}
# item
# {'document': ' Title: Software Licensing Options\n\nRow 1: Single Site License (1 Domain License) - Annual License - 10 Business Email Piping - Unlimited Email Parsing - 1 Year Plugin Update - 1 Year Priority Support - All Features Included\n\nRow 2: Agency License (5 Domain License) - Annual License - 50 Business Email Piping - Unlimited Email Parsing - 1 Year Plugin Update - 1 Year Priority Support - All Features Included\n\nRow 3: 50 Sites License (50 Domain License) - Annual License - 500 Business Email Piping - Unlimited Email Parsing - 1 Year Plugin Update - 1 Year Priority Support - All Features Included\n\nRow 4: Single Site License (1 Domain License) - 1 Year Plugin Update - 1 Year Priority Support - All Features Included\n\nRow 5: Agency License (5 Domain License) - 1 Year Plugin Update - 1 Year Priority Support - All Features Included\n\nRow 6: 50 Sites License (50 Domain License) - 1 Year Plugin Update - 1 Year Priority Support - All Features Included', 'metadata': {'source': '..\\Data\\HTML\\page_20.html', 'type': 'table_summary', 'table_index': 1}, 'id': '2ec281eb-180a-4fd6-97e3-51d4b928320c_table_1'}
# item
# {'document': ' Title: Employee Salary Information by Position and Office Location\n\nZorita Serrano: Software Engineer in San Francisco with a salary of $115,000\nZenaida Frank: Software Engineer in New York with a salary of $125,250\nYuri Berry: Chief Marketing Officer (CMO) in New York with a salary of $675,000\nVivian Harrell: Financial Controller in San Francisco with a salary of $452,500\nUnity Butler: Marketing Designer in San Francisco with a salary of $85,675\nTimothy Mooney: Office Manager in London with a salary of $136,200\nTiger Nixon: System Architect in Edinburgh with a salary of $320,800\n\nNote: The last row contains placeholder text and should be disregarded.', 'metadata': {'source': '..\\Data\\HTML\\page_20.html', 'type': 'table_summary', 'table_index': 2}, 'id': '2ec281eb-180a-4fd6-97e3-51d4b928320c_table_2'}
# item
# {'document': ' Title: iPhone 13 vs. iPhone 12 Specifications\n\nComparison:\n- iPhone 13\n- iPhone 12\n\nPreview:\n- N/A\n- N/A\n\nAnnounced:\n- 2022, February 09\n- 2021, September 13\n\nStatus:\n- Available. Released 2022, February 24\n- Available. Released 2021, September 25\n\nSize:\n- 6.1 inches\n- 6.1 inches\n\nWeight:\n- 6.14 ounces\n- 5.78 ounces\n\nProcessor:\n- A15\n- A14\n\nChipset:\n- Apple A15 Bionic (5 nm)\n- Exynos 2200 (4 nm) - Europe\n\nCamera:\n- 12 MP, f/1.6, 26mm (wide), 1.7µm, dual pixel PDAF, sensor-shift OIS\n- 12 MP, f/1.6, 26mm (wide), 1.7µm, dual pixel PDAF, sensor-shift OIS\n\nBattery:\n- Li-Ion 3240 mAh, non-removable\n- Li-Ion 3000 mAh, non-removable\n\nResolution:\n- 2532x1170\n- 2532x1170', 'metadata': {'source': '..\\Data\\HTML\\page_20.html', 'type': 'table_summary', 'table_index': 3}, 'id': '2ec281eb-180a-4fd6-97e3-51d4b928320c_table_3'}
# item
# {'document': ' Title: Movie Ratings and Information\n\nRow 1: NaN - Minions: The Rise of Gru - Rating: 6.6 - Trailer: NaN - IMDB Link: Learn more\nRow 2: NaN - 12 Angry Men - Rating: 8.9 - Trailer: NaN - IMDB Link: Learn more\nRow 3: NaN - Pulp Fiction - Rating: 8.9 - Trailer: NaN - IMDB Link: Learn more\nRow 4: NaN - The Dark Knight - Rating: 9.3 - Trailer: NaN - IMDB Link: Learn more', 'metadata': {'source': '..\\Data\\HTML\\page_20.html', 'type': 'table_summary', 'table_index': 4}, 'id': '2ec281eb-180a-4fd6-97e3-51d4b928320c_table_4'}
# Num of Table Elements: 1
# Num of Parent Table Elements: 1
# Num of Filtered Parent Table Elements: 1
# Table 0
# item
# {'document': ' Title: Referential Integrity Options in Database Relationships\n\n0. Enforce Referential Integrity: This option prevents invalid data and keeps references in sync across table relationships. It is useful in one-to-one relationships but may create orphans in one-to-many relationships.\n\n1. Cascade Update Related Fields: This option ensures that data in related fields is updated in all related tables when a change is made to a field in the parent table.\n\n2. Cascade Delete Related Records: This option determines whether records in some tables are retained when records are deleted from other tables. If selected, all records referencing the deleted Shipper ID will also be deleted, such as orders in the Orders table. Use with caution.', 'metadata': {'source': '..\\Data\\HTML\\page_3.html', 'type': 'table_summary', 'table_index': 0}, 'id': '7cbbd9ed-f636-4e83-a7a9-1a02eecfb05a_table_0'}
# Num of Table Elements: 1
# Num of Parent Table Elements: 1
# Num of Filtered Parent Table Elements: 1
# Table 0
# item
# {'document': ' Title: "How to Select Data in a Table"\n\n1. To select the entire table, rest the pointer over the table until the table move handle appears, and then click the table move handle.\n2. To select a row or rows, click to the left of the row.\n3. To select a column or columns, click the column\'s top gridline or border.\n4. To select a cell, click the left edge of the cell.', 'metadata': {'source': '..\\Data\\HTML\\page_4.html', 'type': 'table_summary', 'table_index': 0}, 'id': 'cb7b42c5-d344-4226-ac7d-0c1dd4913762_table_0'}
# Num of Table Elements: 7
# Num of Parent Table Elements: 7
# Num of Filtered Parent Table Elements: 7
# Table 0
# Table 1
# Table 2
# Table 3
# Table 4
# Table 5
# Table 6
# item
# {'document': ' Title: Excel Formula Comparison: Cell References vs. Table and Column Names\n\nRow 1:\n- Instead of using explicit cell references like =Sum(C2:C7), Excel allows users to use table and column names for a more efficient and organized approach.\n\nRow 2:\n- For example, instead of referencing a range of cells, users can use table and column names like =SUM(DeptSales[Sales Amount]) for a cleaner and more manageable formula.', 'metadata': {'source': '..\\Data\\HTML\\page_5.html', 'type': 'table_summary', 'table_index': 0}, 'id': 'a90fc152-05a5-4c66-aea4-ecc3a94beba6_table_0'}
# item
# {'document': ' Title: Sales Commission Summary\n\nJoe: North region, $260 sales amount, 10% commission rate, commission amount NaN\nRobert: South region, $660 sales amount, 15% commission rate, commission amount NaN\nMichelle: East region, $940 sales amount, 15% commission rate, commission amount NaN\nErich: West region, $410 sales amount, 12% commission rate, commission amount NaN\nDafna: North region, $800 sales amount, 15% commission rate, commission amount NaN\nRob: South region, $900 sales amount, 15% commission rate, commission amount NaN', 'metadata': {'source': '..\\Data\\HTML\\page_5.html', 'type': 'table_summary', 'table_index': 1}, 'id': 'a90fc152-05a5-4c66-aea4-ecc3a94beba6_table_1'}
# item
# {'document': ' Title: Excel Formula Reference Operators\n\n1. The first row refers to using the colon range operator (:) to select all of the cells in two or more adjacent columns. In this example, it selects the range A2:B7.\n2. The second row demonstrates the use of the comma union operator (,) to combine two or more columns. In this case, it selects the ranges C2:C7 and E2:E7.\n3. The third row shows the intersection operator (space) to select the intersection of two or more columns. Here, it selects the range B2:C7.', 'metadata': {'source': '..\\Data\\HTML\\page_5.html', 'type': 'table_summary', 'table_index': 2}, 'id': 'a90fc152-05a5-4c66-aea4-ecc3a94beba6_table_2'}
# item
# {'document': " Title: Table Special Item Specifiers Summary\n\n1. #All: Represents the entire table, including column headers, data, and totals (if any).\n2. #Data: Represents just the data rows of the table.\n3. #Headers: Represents just the header row of the table.\n4. #Totals: Represents just the total row, if it exists, otherwise returns null.\n5. #This Row or @ or @[Column Name]: Represents the cells in the same row as the formula. These specifiers can't be combined with any other special item specifiers and are used to force implicit intersection behavior or to override it and refer to single values from a column. In tables with more than one row, Excel automatically changes #This Row specifiers to the shorter @ specifier. However, if the table has only one row, Excel doesn't replace the #This Row specifier, which may cause calculation problems. To avoid these issues, ensure you enter multiple rows in the table before using structured reference formulas.", 'metadata': {'source': '..\\Data\\HTML\\page_5.html', 'type': 'table_summary', 'table_index': 3}, 'id': 'a90fc152-05a5-4c66-aea4-ecc3a94beba6_table_3'}
# item
# {'document': ' Title: Types of Structured References in Formulas\n\nUnqualified: Multiplies corresponding values from the current row (e.g., [Sales Amount]*[% Commission]).\nFully qualified: Multiplies corresponding values for each row for both columns (e.g., DeptSales[Sales Amount]*DeptSales[% Commission]).', 'metadata': {'source': '..\\Data\\HTML\\page_5.html', 'type': 'table_summary', 'table_index': 4}, 'id': 'a90fc152-05a5-4c66-aea4-ecc3a94beba6_table_4'}
# item
# {'document': ' Title: Explanation of Structured References in a Table\n\n1. Refers to all the cells in the Sales Amount column (C1:C8).\n2. Refers to the header of the % Commission column (D1).\n3. Refers to the total of the Region column (B8).\n4. Refers to all the cells in Sales Amount and % Commission columns (C1:D8).\n5. Refers to just the data of the % Commission and Commission Amount columns (D2:E7).\n6. Refers to just the headers of the columns between Region and Commission Amount (B1:E1).\n7. Refers to the totals of the Sales Amount through Commission Amount columns (C8:E8).\n8. Refers to just the header and the data of % Commission (D1:D7).\n9. Refers to the cell at the intersection of the current row and the Commission Amount column (E5 if the current row is 5).', 'metadata': {'source': '..\\Data\\HTML\\page_5.html', 'type': 'table_summary', 'table_index': 5}, 'id': 'a90fc152-05a5-4c66-aea4-ecc3a94beba6_table_5'}
# item
# {'document': ' Title: Filling Table with Column Specifiers\n\n1. If the fill direction is Up or Down and nothing is pressed, there is no column specifier adjustment.\n2. If the fill direction is Up or Down and Ctrl is pressed, column specifiers adjust like a series.\n3. If the fill direction is Right or Left, no action is taken and column specifiers adjust like a series.\n4. If the fill direction is Up, Down, Right, or Left and Shift is pressed, current cell values are moved and column specifiers are inserted.', 'metadata': {'source': '..\\Data\\HTML\\page_5.html', 'type': 'table_summary', 'table_index': 6}, 'id': 'a90fc152-05a5-4c66-aea4-ecc3a94beba6_table_6'}
# Num of Table Elements: 2
# Num of Parent Table Elements: 2
# Num of Filtered Parent Table Elements: 2
# Table 0
# Table 1
# item
# {'document': ' Title: Sales Data Summary\n\n1. Order ID 20050, Sale Date 2/2/14, Product ID C6077B\n2. Order ID 20050, Sale Date 2/2/14, Product ID C9250LB\n3. Order ID 20051, Sale Date 2/2/14, Product ID M115A\n4. Order ID 20052, Sale Date 2/3/14, Product ID A760G\n5. Order ID 20052, Sale Date 2/3/14, Product ID E3331\n6. Order ID 20052, Sale Date 2/3/14, Product ID SP1447\n7. Order ID 20053, Sale Date 2/3/14, Product ID L88M\n8. Order ID 20054, Sale Date 2/4/14, Product ID S1018MM\n9. Order ID 20055, Sale Date 2/5/14, Product ID C6077B\n10. Order ID 20056, Sale Date 2/6/14, Product ID E3331\n11. Order ID 20056, Sale Date 2/6/14, Product ID D534X', 'metadata': {'source': '..\\Data\\HTML\\page_6.html', 'type': 'table_summary', 'table_index': 0}, 'id': '40954aa6-d6c7-4e69-b59a-88af617204dc_table_0'}
# item
# {'document': ' Title: Sales Data by Region\n\n1. Order ID 20050 corresponds to Sales ID 447 in the West region.\n2. Order ID 20051 corresponds to Sales ID 398 in the South region.\n3. Order ID 20052 corresponds to Sales ID 1006 in the North region.\n4. Order ID 20053 corresponds to Sales ID 447 in the West region.\n5. Order ID 20054 corresponds to Sales ID 885 in the East region.\n6. Order ID 20055 corresponds to Sales ID 398 in the South region.\n7. Order ID 20056 corresponds to Sales ID 644 in the East region.\n8. Order ID 20057 corresponds to Sales ID 1270 in the East region.\n9. Order ID 20058 corresponds to Sales ID 885 in the East region.', 'metadata': {'source': '..\\Data\\HTML\\page_6.html', 'type': 'table_summary', 'table_index': 1}, 'id': '40954aa6-d6c7-4e69-b59a-88af617204dc_table_1'}
# Num of Table Elements: 2
# Num of Parent Table Elements: 2
# Num of Filtered Parent Table Elements: 2
# Table 0
# Table 1
# item
# {'document': ' Title: Database Subform Control Properties and Usage\n\n1. Subform control: A control that embeds a form within another form, allowing for linked data display.\n2. Source Object property: Determines the object displayed in the subform control (form, table, or query).\n3. Datasheet: A simple data display in rows and columns, used when the source object is a table, query, or form with Datasheet view.\n4. Link Child Fields property: Specifies fields linking the subform to the main form.\n5. Link Master Fields property: Specifies fields on the main form linking to the subform.', 'metadata': {'source': '..\\Data\\HTML\\page_7.html', 'type': 'table_summary', 'table_index': 0}, 'id': '706429f6-c07e-441a-9764-bd91e49fc7c8_table_0'}
# item
# {'document': ' Title: "Creating and Adding Subforms to Main Forms in Access"\n\n1. To create a form with a main form and a subform, and link them together, use the Form Wizard.\n2. To use an existing form as the main form and create a new subform, add it to the main form using the Subform Wizard.\n3. To use an existing form as the main form and add existing forms as subforms, simply drag one form onto another.', 'metadata': {'source': '..\\Data\\HTML\\page_7.html', 'type': 'table_summary', 'table_index': 1}, 'id': '706429f6-c07e-441a-9764-bd91e49fc7c8_table_1'}
# Num of Table Elements: 6
# Num of Parent Table Elements: 6
# Num of Filtered Parent Table Elements: 6
# Table 0
# Table 1
# Table 2
# Table 3
# Table 4
# Table 5
# item
# {'document': ' Title: Customer Orders and Discount Rates\n\nRow 1: Ashton with email chris.ashton@contoso.com has a 5% discount rate. They ordered Compact Digital (11 units) and SLR Camera (15 units) on January 7th and January 3rd, 2010 respectively.\n\nRow 2: Jaworski with email michal.jaworski@contoso.com has a 10% discount rate. They ordered Budget Movie-Maker (27 units) on January 3rd, 2010.', 'metadata': {'source': '..\\Data\\HTML\\page_8.html', 'type': 'table_summary', 'table_index': 0}, 'id': 'd98796d9-28f4-440b-b8e2-bc092f0c42f3_table_0'}
# item
# {'document': ' Title: Customer Information\n\nRow 1: CustomerID 1, Name Ashton, Email chris.ashton@contoso.com\nRow 2: CustomerID 2, Name Jaworski, Email michal.jaworski@contoso.com', 'metadata': {'source': '..\\Data\\HTML\\page_8.html', 'type': 'table_summary', 'table_index': 1}, 'id': 'd98796d9-28f4-440b-b8e2-bc092f0c42f3_table_1'}
# item
# {'document': ' Title: Customer Discount Rates\n\nRow 1: CustomerID 1 receives a 5% discount rate.\nRow 2: CustomerID 2 receives a 10% discount rate.', 'metadata': {'source': '..\\Data\\HTML\\page_8.html', 'type': 'table_summary', 'table_index': 2}, 'id': 'd98796d9-28f4-440b-b8e2-bc092f0c42f3_table_2'}
# item
# {'document': ' Title: Customer Orders Summary\n\nRow 1: Customer ID 1 placed an order for 11 Compact Digital products on January 7, 2010.\nRow 2: Customer ID 1 also placed an order for 15 SLR Cameras on January 3, 2010.\nRow 3: Customer ID 2 placed an order for 27 Budget Movie-Makers on January 3, 2010.', 'metadata': {'source': '..\\Data\\HTML\\page_8.html', 'type': 'table_summary', 'table_index': 3}, 'id': 'd98796d9-28f4-440b-b8e2-bc092f0c42f3_table_3'}
# item
# {'document': ' Title: "Customer Relationships and Lookup Columns"\n\n1. Customers-CustomerDiscounts: A one-to-one relationship where the CustomerID is used in both Customers.CustomerID and CustomerDiscounts.CustomerID columns.\n2. Customers-Orders: A one-to-many relationship where the CustomerID is used in both Customers.CustomerID and Orders.CustomerID columns.', 'metadata': {'source': '..\\Data\\HTML\\page_8.html', 'type': 'table_summary', 'table_index': 4}, 'id': 'd98796d9-28f4-440b-b8e2-bc092f0c42f3_table_4'}
# item
# {'document': ' Title: Data Modeling Criteria and Descriptions\n\n1. Unique Identifier for Each Table: Each table must have a primary key column that uniquely identifies each row.\n2. Unique Lookup Columns: Lookup columns must have unique data values, with no duplicates or nulls.\n3. Compatible Data Types: Source and lookup columns must have compatible data types.', 'metadata': {'source': '..\\Data\\HTML\\page_8.html', 'type': 'table_summary', 'table_index': 5}, 'id': 'd98796d9-28f4-440b-b8e2-bc092f0c42f3_table_5'}
# Num of Table Elements: 1
# Num of Parent Table Elements: 1
# Num of Filtered Parent Table Elements: 1
# Table 0
# item
# {'document': ' Title: XLOOKUP Function Summary\n\n1. lookup_value: The value to search for in the lookup_array. If omitted, XLOOKUP returns blank cells found in lookup_array.\n2. lookup_array: The array or range to search for the lookup_value.\n3. return_array: The array or range to return the corresponding value from when a match is found in lookup_array.\n4. [if_not_found]: Optional text to return when a valid match is not found. If not provided, #N/A is returned.\n5. [match_mode]: Optional match type: 0 (exact match, #N/A if not found), -1 (exact match, return next smaller item if not found), 1 (exact match, return next larger item if not found), or 2 (wildcard match with special characters).\n6. [search_mode]: Optional search mode: 1 (start from the first item), -1 (start from the last item), 2 (binary search with ascending order), or -2 (binary search with descending order).', 'metadata': {'source': '..\\Data\\HTML\\page_9.html', 'type': 'table_summary', 'table_index': 0}, 'id': 'd518e189-3c9d-4de7-b0d3-31c7e6edc78a_table_0'}

# %%
# Split into 3 separate lists

documents_list = []
metadata_list = []
ids_list = []

for doc_info in master_list:
    documents_list.append(doc_info['document'])
    metadata_list.append(doc_info['metadata'])
    ids_list.append(doc_info['id'])

print(f"Documents List: {documents_list}")
print(f"Metadata List: {metadata_list}")
print(f"IDs List: {ids_list}")

# Add data to ChromaDB

collection.add(
    documents=documents_list,
    metadatas=metadata_list,
    ids=ids_list
)
# Out:
# Documents List: [' Title: Data Types in Access Based on User Input\n\n1. If you enter "Short Text", Access creates a field with a data type of Short Text.\n2. If you enter a valid Internet protocol prefix (e.g., http://, https://, mailto:), Access creates a field with a data type of Hyperlink.\n3. If you enter a number, Access creates a field with a data type of Long Integer.\n4. If you enter a date and time, Access creates a field with a data type of Date/Time. The format recognized is based on the user\'s locale.\n5. If you enter a currency value, Access creates a field with a data type of Currency. The currency symbol recognized is based on the user\'s locale.\n6. If you enter a percentage value, Access creates a field with a data type of Double.\n7. If you enter a scientific notation value, Access creates a field with a data type of Double.', 'Introduction to tables - Microsoft Support Skip to main content Microsoft Support Support Support Home Microsoft 365 Office Products Microsoft 365 Outlook Microsoft Teams OneDrive OneNote Windows Microsoft Edge more ... Devices Surface PC Accessories Mobile Xbox PC Gaming HoloLens Hardware warranties Account & billing Account Microsoft Store & billing Resources Install Microsoft 365 Community forums Microsoft 365 Admins Small Business Portal Developer Education Report a support scam More Buy Microsoft 365 All Microsoft Global Microsoft 365 Teams Copilot Windows Surface Xbox Deals Small Business Support Software Software Windows Apps AI Outlook OneDrive Microsoft Teams OneNote Microsoft Edge Skype PCs & Devices PCs & Devices Computers Shop Xbox Accessories VR & mixed reality Certified Refurbished Trade-in for cash Entertainment Entertainment Xbox Game Pass Ultimate PC Game Pass Xbox games PC and Windows games Movies & TV Business Business Microsoft Cloud Microsoft Security Dynamics 365 Microsoft 365 for busine', 'Movies & TV Business Business Microsoft Cloud Microsoft Security Dynamics 365 Microsoft 365 for business Microsoft Power Platform Windows 365 Microsoft Industry Small Business Developer & IT Developer & IT Azure Developer Center Documentation Microsoft Learn Microsoft Tech Community Azure Marketplace AppSource Visual Studio Other Other Microsoft Rewards Free downloads & security Education Gift cards Licensing Unlocked stories View Sitemap Search Search for help No results Cancel Sign in Sign in with Microsoft Sign in or create an account. Hello, Select a different account. You have multiple accounts Choose the account you want to sign in with. Access Tables Creating tables Creating tables Introduction to tables Introduction to tables Access for Microsoft 365 Access 2021 Access 2019 Access 2016 Access 2013 More... Less Tables are essential objects in a database because they hold all the information or data. For example, a database for a business can have a Contacts table that stores the names of their supplier', 'r example, a database for a business can have a Contacts table that stores the names of their suppliers, e-mail addresses, and telephone numbers. Because other database objects depend so heavily on tables, you should always start your design of a database by creating all of its tables and then creating any other objects. Before you create tables in Access, consider your requirements and determine all the tables that you might need. For an introduction to planning and designing a database, see Database design basics . In this article Overview Table and field properties Data Types Table relationships Keys Benefits of using relationships Overview A relational database like Access usually has several related tables. In a well-designed database, each table stores data about a particular subject, such as employees or products. A table has records (rows) and fields (columns). Fields have different types of data, such as text, numbers, dates, and hyperlinks. A record: Contains specific data, like information about a ', "h as text, numbers, dates, and hyperlinks. A record: Con ...
# Metadata List: [{'source': '..\\Data\\HTML\\page_1.html', 'type': 'table_summary', 'table_index': 0}, {'source': '..\\Data\\HTML\\page_1.html', 'ind': 0}, {'source': '..\\Data\\HTML\\page_1.html', 'ind': 1}, {'source': '..\\Data\\HTML\\page_1.html', 'ind': 2}, {'source': '..\\Data\\HTML\\page_1.html', 'ind': 3}, {'source': '..\\Data\\HTML\\page_1.html', 'ind': 4}, {'source': '..\\Data\\HTML\\page_1.html', 'ind': 5}, {'source': '..\\Data\\HTML\\page_1.html', 'ind': 6}, {'source': '..\\Data\\HTML\\page_1.html', 'ind': 7}, {'source': '..\\Data\\HTML\\page_1.html', 'ind': 8}, {'source': '..\\Data\\HTML\\page_1.html', 'ind': 9}, {'source': '..\\Data\\HTML\\page_1.html', 'ind': 10}, {'source': '..\\Data\\HTML\\page_1.html', 'ind': 11}, {'source': '..\\Data\\HTML\\page_1.html', 'ind': 12}, {'source': '..\\Data\\HTML\\page_10.html', 'ind': 0}, {'source': '..\\Data\\HTML\\page_10.html', 'ind': 1}, {'source': '..\\Data\\HTML\\page_10.html', 'ind': 2}, {'source': '..\\Data\\HTML\\page_10.html', 'ind': 3}, {'source': '..\\Data\\HTML\\page_10.html', 'ind': 4}, {'source': '..\\Data\\HTML\\page_10.html', 'ind': 5}, {'source': '..\\Data\\HTML\\page_10.html', 'ind': 6}, {'source': '..\\Data\\HTML\\page_10.html', 'ind': 7}, {'source': '..\\Data\\HTML\\page_10.html', 'ind': 8}, {'source': '..\\Data\\HTML\\page_10.html', 'ind': 9}, {'source': '..\\Data\\HTML\\page_10.html', 'ind': 10}, {'source': '..\\Data\\HTML\\page_10.html', 'ind': 11}, {'source': '..\\Data\\HTML\\page_11.html', 'type': 'table_summary', 'table_index': 0}, {'source': '..\\Data\\HTML\\page_11.html', 'type': 'table_summary', 'table_index': 1}, {'source': '..\\Data\\HTML\\page_11.html', 'type': 'table_summary', 'table_index': 2}, {'source': '..\\Data\\HTML\\page_11.html', 'ind': 0}, {'source': '..\\Data\\HTML\\page_11.html', 'ind': 1}, {'source': '..\\Data\\HTML\\page_11.html', 'ind': 2}, {'source': '..\\Data\\HTML\\page_11.html', 'ind': 3}, {'source': '..\\Data\\HTML\\page_11.html', 'ind': 4}, {'source': '..\\Data\\HTML\\page_11.html', 'ind': 5}, {'source': '..\\Data\\HTML\\page_12.html', 'type': 'table_summary', 'table_index': 0}, {'source': '..\\Data\\HTML\\page_12.html', 'type': 'table_summary', 'table_index': 1}, {'source': '..\\Data\\HTML\\page_12.html', 'type': 'table_summary', 'table_index': 2}, {'source': '..\\Data\\HTML\\page_12.html', 'type': 'table_summary', 'table_index': 3}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 0}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 1}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 2}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 3}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 4}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 5}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 6}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 7}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 8}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 9}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 10}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 11}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 12}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 13}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 14}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 15}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 16}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 17}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 18}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 19}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 20}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 21}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 22}, {'source': '..\\Data\\HTML\\page_12.html', 'ind': 23}, {'source': '..\\Data\\HTML\\page_13.html', 'type': 'table_summary', 'table_index': 0}, {'source': '..\\Data\\HTML\\page_13.html', 'type': 'table_summary', 'table_index': 1}, {'source': '..\\Data\\HTML\\page_13.html', 'ind': 0}, {'source': '..\\Data\\HTML\\page_13.html', 'ind': 1}, {'source': '..\\Data\\HTML\\pag ...
# IDs List: ['974afc9b-16d7-4c53-b5ca-24530f6f9795_table_0', '974afc9b-16d7-4c53-b5ca-24530f6f9795_1', '974afc9b-16d7-4c53-b5ca-24530f6f9795_2', '974afc9b-16d7-4c53-b5ca-24530f6f9795_3', '974afc9b-16d7-4c53-b5ca-24530f6f9795_4', '974afc9b-16d7-4c53-b5ca-24530f6f9795_5', '974afc9b-16d7-4c53-b5ca-24530f6f9795_6', '974afc9b-16d7-4c53-b5ca-24530f6f9795_7', '974afc9b-16d7-4c53-b5ca-24530f6f9795_8', '974afc9b-16d7-4c53-b5ca-24530f6f9795_9', '974afc9b-16d7-4c53-b5ca-24530f6f9795_10', '974afc9b-16d7-4c53-b5ca-24530f6f9795_11', '974afc9b-16d7-4c53-b5ca-24530f6f9795_12', '974afc9b-16d7-4c53-b5ca-24530f6f9795_13', '21f0ee37-d83e-4d22-8dab-8f2fbdfc5b39_0', '21f0ee37-d83e-4d22-8dab-8f2fbdfc5b39_1', '21f0ee37-d83e-4d22-8dab-8f2fbdfc5b39_2', '21f0ee37-d83e-4d22-8dab-8f2fbdfc5b39_3', '21f0ee37-d83e-4d22-8dab-8f2fbdfc5b39_4', '21f0ee37-d83e-4d22-8dab-8f2fbdfc5b39_5', '21f0ee37-d83e-4d22-8dab-8f2fbdfc5b39_6', '21f0ee37-d83e-4d22-8dab-8f2fbdfc5b39_7', '21f0ee37-d83e-4d22-8dab-8f2fbdfc5b39_8', '21f0ee37-d83e-4d22-8dab-8f2fbdfc5b39_9', '21f0ee37-d83e-4d22-8dab-8f2fbdfc5b39_10', '21f0ee37-d83e-4d22-8dab-8f2fbdfc5b39_11', '33148ddd-1304-4cc4-93b2-0b3749560730_table_0', '33148ddd-1304-4cc4-93b2-0b3749560730_table_1', '33148ddd-1304-4cc4-93b2-0b3749560730_table_2', '33148ddd-1304-4cc4-93b2-0b3749560730_3', '33148ddd-1304-4cc4-93b2-0b3749560730_4', '33148ddd-1304-4cc4-93b2-0b3749560730_5', '33148ddd-1304-4cc4-93b2-0b3749560730_6', '33148ddd-1304-4cc4-93b2-0b3749560730_7', '33148ddd-1304-4cc4-93b2-0b3749560730_8', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_table_0', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_table_1', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_table_2', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_table_3', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_4', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_5', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_6', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_7', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_8', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_9', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_10', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_11', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_12', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_13', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_14', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_15', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_16', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_17', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_18', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_19', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_20', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_21', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_22', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_23', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_24', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_25', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_26', '268ed106-e1db-4b61-b4b7-a3eab5fd8608_27', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_table_0', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_table_1', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_2', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_3', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_4', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_5', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_6', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_7', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_8', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_9', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_10', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_11', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_12', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_13', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_14', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_15', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_16', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_17', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_18', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_19', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_20', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_21', 'b5d7d53b-f828-41a5-acd1-5a0c2c2b3f64_22', '3135dcf7-c7ac-45f1-9c06-c1c37d76bd4f_table_0', '3135dcf7-c7ac-45f1-9c06-c1c37d76bd4f_table_1', '3135dcf7-c7ac-45f1-9c06-c1c37d76bd4f_2', '3135dcf7-c7ac-45f1-9c06-c1c37d76bd4f_3', '3135dcf7-c7ac-45f1-9c06-c1c37d76bd4f_4', '3135dcf7-c7ac-45f1-9c06-c1c37d76bd4f_5', '3135dcf7-c7ac-4 ...

# %%
# query = f"what is the fat rate for Louisiana state"
query = f"how many states have fat rate below 40"

# TODO: Have a way to flter by metadata for cases where we want to answer something like how many tables in <url>
results = collection.query(
    query_texts=query,
    n_results=5
)
print(f"results\n:{results}")

payload = {
    'messages': [
        {
            'role': 'system', 
            'content': f"You are a helpful assistant. Without any prior context answer the user's qustion based on the context provided only."
        },
        {
            'role': 'user',
            'content': f"{query}\nContext\n{results}"
        }
    ],
    'model': "gpt-4-turbo-preview",
    'max_tokens': 128,
    "temperature": 0.0,
    'seed': 48
}
input_tokens, output_tokens, response = make_openai_call(payload)
print(f"input tokens: {input_tokens}")
print(f"output tokens: {output_tokens}")
print(f"response: {response}")
# Out:
# results
# :{'ids': [['d30870f3-f829-41a9-bb8b-15e1b5df3853_table_0', 'd30870f3-f829-41a9-bb8b-15e1b5df3853_7', 'd30870f3-f829-41a9-bb8b-15e1b5df3853_6', 'd30870f3-f829-41a9-bb8b-15e1b5df3853_5', 'd30870f3-f829-41a9-bb8b-15e1b5df3853_12']], 'distances': [[0.729601263999939, 0.931536078453064, 0.9675045013427734, 0.9688311219215393, 1.028817057609558]], 'metadatas': [[{'source': '..\\Data\\HTML\\page_19.html', 'table_index': 0, 'type': 'table_summary'}, {'ind': 6, 'source': '..\\Data\\HTML\\page_19.html'}, {'ind': 5, 'source': '..\\Data\\HTML\\page_19.html'}, {'ind': 4, 'source': '..\\Data\\HTML\\page_19.html'}, {'ind': 11, 'source': '..\\Data\\HTML\\page_19.html'}]], 'embeddings': None, 'documents': [[' Title: "Top 10 U.S. States with the Highest Obesity Rates"\n\n1. Mississippi: 40.8% obesity rate\n2. West Virginia: 39.7% obesity rate\n3. Arkansas: 37.4% obesity rate\n4. Oklahoma: 36.8% obesity rate\n5. Kentucky: 36.5% obesity rate\n6. Tennessee: 36.5% obesity rate\n7. Alabama: 36.1% obesity rate\n8. Michigan: 36% obesity rate\n9. Louisiana: 35.9% obesity rate\n10. South Carolina: 35.4% obesity rate', 'another factor that is important to consider when talking about obese Americans. The data supports the many anecdotal news stories about overweight Americans. 40% of adult Americans that are aged 20-39 are obese. 45% of adult Americans that are aged 40-59 are obese. 43% of adult Americans that are aged 60 and older are obese. Nearly one-half (49.1%) of adults tried to lose weight within the last 12 months. 42.7% older adults aged 60 and over tried to lose weight 49.7% younger adults aged 20–39 tried to lose weight 52.4% of middle-aged adults aged 40–59 tried to lose weight Source: CDC Does Geography Matter for Weight Loss and Obesity? Here are the 10 states with the highest rates of obesity: How Did the Covid Pandemic Impact Weight Loss? An APA Stress in America survey conducted in late February 2021 found 42% of U.S. adults reported undesired weight gain since the start of the pandemic, with an average gain of 29 pounds . With the pandemic still raging in 2021, maintaining a healthy weight is the primary con', " Caucasians. The South and the Midwest have the highest obesity prevalence. All U.S. states and territories have an obesity rate of at least 20% Source: Centers for Disease Control and Prevention, 2020 In-Person Training Get trained in medical weight management from industry professionals at the Aesthetic Medicine Symposium. I'M READY - START TRAINING NOW The Weight Loss Time-Bomb & The Cost of Obesity This is not a problem that will go away any time soon. Within the next decade, it is likely that 50% of Americans will be obese and 20% will be diabetic. The hard costs today today include: The medical care costs of obesity are almost $150 billion per year in the U.S. Obese individuals spend about $1,500 more on medical care for themselves than people of healthy weight. Obesity-related medical costs could rise by $48 to $66 billion per year by 2030. Source: Harvard Does Age Affect Obesity & Weight Loss? Age is another factor that is important to consider when talking about obese Americans. The data supports the", 'o reach $377.3 billion by 2026. The biggest opportunity for growth in the Weight Loss Services industry in the US is related to the adult obesity rate, which measures the percentage of US citizens aged 20 and older whose BMI is 30.0 or higher. As the prevalence of adult obesity increases, demand for services from the Weight Loss Services industry is expected to increase. Sources: ( Medscape ) "Medical weight loss plans as a niche weight loss business have been outperforming and likely will into the future." Source: ibisworld The Opportunity Cost For Medical Weight Loss With the crushing weight of statistics, can the weight loss service industry meet the needs of the US population? 1 out of every 3 U.S. adults is obese. Non-Hispanic black women experience the highest rates of obesity in America at 59%. Obesity rates are hig ...
# input tokens: 1429
# output tokens: 128
# response: Based on the provided context, 9 out of the top 10 U.S. states with the highest obesity rates have a fat rate (obesity rate) below 40%. These states are:
#
# 1. West Virginia: 39.7% obesity rate
# 2. Arkansas: 37.4% obesity rate
# 3. Oklahoma: 36.8% obesity rate
# 4. Kentucky: 36.5% obesity rate
# 5. Tennessee: 36.5% obesity rate
# 6. Alabama: 36.1% obesity rate
# 7. Michigan: 36% obesity rate
# 8. Louisiana:
